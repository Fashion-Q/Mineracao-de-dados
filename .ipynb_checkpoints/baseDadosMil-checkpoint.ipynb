# %%
import numpy as np
import pandas as pd

# %%
#df = pd.read_excel('BaseDW-MilLinhas.xls')
pathExcel = 'BaseDW-MilLinhas.xls'
allExcelNames = pd.ExcelFile(pathExcel).sheet_names

# %%
for currentExcelName in allExcelNames:
    df = pd.read_excel(caminho_planilha, sheet_name=currentExcelName)
    print(f'Current Table: {currentExcelName}')
    print(df)
# Out:
# Current Table: DIM_Clientes
#    COD_CLIENTE      NOME_CLIENTE SEXO_CLIENTE           BAIRRO       CIDADE  \
# 0            1   Jose dos Testes            M       MANGABEIRA  JOAO PESSOA
# 1            2  Maria dos Testes            F            TIROL        NATAL
# 2            3    Andreia jargão            F  NOVA PARNAMIRIM   PARNAMIRIM
# 3            4     Viviane Maria            F       CANDELARIA        NATAL
# 4            5       Pedro Paulo            M           CENTRO        NATAL
# 5            6     Joao da Silva            M       PETROPOLIS        NATAL
# 6            7      Juarez Teste            M  NOVA PARNAMIRIM   PARNAMIRIM
# 7            8       Joana Maria            F       MANGABEIRA  JOAO PESSOA
# 8            9    Miguel Tavares            M            TIROL        NATAL
# 9           10     Michele Maria            F       CANDELARIA        NATAL
#
#    UF    PAIS
# 0  PB  BRASIL
# 1  RN  BRASIL
# 2  RN  BRASIL
# 3  RN  BRASIL
# 4  RN  BRASIL
# ...
